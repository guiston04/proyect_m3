# %%
import pandas as pd
import numpy as np

# %%
diamonds_test = pd.read_csv('./diamonds_test.csv')
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city
# 0          Amsterdam
# ...

# %%
diamonds = pd.read_csv('./diamonds.csv')
diamonds
# Out:
#        Unnamed: 0                                           index_id  price  \
# 0               0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1               1  248aa2bdd0032920ac9e5f6ad36c350549da067efeaf7b...   4839
# 2               2  72b31cf00f8ab3967588fad4a32f61622cb162f9b7bc2c...    368
# 3               3  98c53df687f2e9b94da80eef5b9049f1fac456b4c41c80...   5053
# 4               4  5dfe43a321c6834c7de273c73aeadc705d919a5869e0f5...   3593
# ...           ...                                                ...    ...
# 40450       40450  097db724e4c3e305e3cab516a90727b5ba198654479af6...   2632
# 40451       40451  7a2f5310cf8293f60a9103040d9a0ac0a9ce1d625f5121...   9972
# 40452       40452  7d6fb002a947a9c894eb5c2a5a12be30cb7d4af83a29d9...    886
# 40453       40453  7880bd7fe5dcd28637eade8b95c42961c6c5acffa946a6...   3205
# 40454       40454  bfcae0114088c1767863ef9463f93f442215b9c671c24e...   1166
#
# ...

# %%
diamonds.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
import matplotlib.pyplot as plt
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(diamonds_test['carat'])
 
# show plot
plt.show()

# %%
diamonds_test.describe()
# Out:
#                  id         carat         depth         table             x  \
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean    6742.000000      0.798642     61.739095     57.490337      5.736454
# std     3892.928525      0.469399      1.435310      2.237109      1.113671
# min        0.000000      0.200000     50.800000     51.000000      0.000000
# 25%     3371.000000      0.400000     61.000000     56.000000      4.730000
# 50%     6742.000000      0.700000     61.900000     57.000000      5.700000
# 75%    10113.000000      1.040000     62.500000     59.000000      6.530000
# max    13484.000000      5.010000     79.000000     73.000000     10.740000
#
#                   y             z
# count  13485.000000  13485.000000
# mean       5.739648      3.543474
# std        1.128507      0.731005
# min        0.000000      0.000000
# 25%        4.730000      2.920000
# 50%        5.720000      3.530000
# 75%        6.530000      4.040000
# ...

# %%
diamonds.describe()
# Out:
#               price         carat         depth         table             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean    3928.444469      0.797706     61.752841     57.446133      5.729392
# std     3992.416147      0.475544      1.431725      2.233535      1.124453
# min      326.000000      0.200000     43.000000     43.000000      0.000000
# 25%      945.000000      0.400000     61.000000     56.000000      4.710000
# 50%     2397.000000      0.700000     61.800000     57.000000      5.690000
# 75%     5331.000000      1.040000     62.500000     59.000000      6.540000
# max    18823.000000      4.500000     79.000000     95.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# ...

# %%
diamonds_test['color'].unique()
# Out:
# array(['F', 'J', 'H', 'D', 'I', 'G', 'E'], dtype=object)

# %%
diamonds['color'].unique()
# Out:
# array(['J', 'I', 'G', 'D', 'H', 'E', 'F'], dtype=object)

# %%
a = diamonds_test.groupby(by=['color','cut', 'color']).mean()
a
# Out:
#                                 id     carat      depth      table         x  \
# color cut       color
# D     Fair      D      7515.777778  0.880833  63.683333  60.194444  5.955556
#       Good      D      7042.370588  0.785941  62.168235  58.712941  5.718471
#       Ideal     D      6855.140118  0.583304  61.649263  56.045870  5.233024
#       Premium   D      6386.602679  0.726875  61.107813  58.892857  5.612455
#       Very Good D      7160.236041  0.692741  61.764721  57.995178  5.490508
# E     Fair      E      6446.910714  0.860893  63.121429  59.583929  5.905179
#       Good      E      6720.004115  0.766214  62.128395  58.762551  5.669877
#       Ideal     E      6766.321501  0.573337  61.715619  55.977586  5.206785
#       Premium   E      6867.152824  0.705066  61.196844  58.812292  5.557724
#       Very Good E      6568.276923  0.675197  61.745470  57.912308  5.422855
# F     Fair      F      6802.744186  0.955116  63.293023  59.618605  6.104651
# ...

# %%
b = diamonds.groupby(by=['color','cut', 'color']).mean()
b
# Out:
#                              price     carat      depth      table         x  \
# color cut       color
# D     Fair      D      4352.748031  0.931260  64.151969  58.622047  6.036142
#       Good      D      3311.693089  0.730203  62.433943  58.482317  5.586077
#       Ideal     D      2579.709647  0.560250  61.687523  55.940399  5.172138
#       Premium   D      3638.838961  0.719481  61.193074  58.651515  5.594987
#       Very Good D      3468.689008  0.697721  61.745040  58.057551  5.504978
# E     Fair      E      3609.880952  0.855179  63.385714  59.291667  5.910357
#       Good      E      3399.881159  0.737710  62.230290  58.786087  5.599580
#       Ideal     E      2624.818649  0.580113  61.676894  55.964038  5.218797
#       Premium   E      3578.086455  0.722144  61.168646  58.768069  5.597314
#       Very Good E      3198.432507  0.676678  61.725344  58.079669  5.435565
# F     Fair      F      3699.176991  0.885531  63.589823  59.390265  5.947080
# ...

# %%
test = pd.read_csv('./test.csv')
test
# Out:
#        Unnamed: 0     id  carat        cut color clarity  depth  table     x  \
# 0               0      0   0.79  Very Good     F     SI1   62.7   60.0  5.82
# 1               1      1   1.20      Ideal     J     VS1   61.0   57.0  6.81
# 2               2      2   1.57    Premium     H     SI1   62.2   61.0  7.38
# 3               3      3   0.90  Very Good     F     SI1   63.8   54.0  6.09
# 4               4      4   0.50  Very Good     F     VS1   62.9   58.0  5.05
# ...           ...    ...    ...        ...   ...     ...    ...    ...   ...
# 13480       13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35
# 13481       13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71
# 13482       13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75
# 13483       13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85
# 13484       13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70
#
# ...

# %%
test.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
a = test[['carat','Price']]
a = a.groupby(by = 'carat', as_index = False).mean()

# %%
a
# Out:
#      carat         Price
# 0     0.20    416.759556
# 1     0.23    464.260591
# 2     0.24    484.576211
# 3     0.25    538.102665
# 4     0.26    533.973225
# ..     ...           ...
# 229   3.01  17624.791667
# 230   3.04  17462.425000
# 231   3.65  17494.548333
# 232   3.67  17822.020000
# 233   5.01  17518.423333
#
# [234 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
  
plt.plot(a['carat'], a['Price'])  # Plot the chart
plt.show()  # display

# %%
test_join = test[['carat', 'cut', 'color', 'clarity', 'Price']]
diamonds_join = diamonds[['carat', 'cut', 'color', 'clarity', 'price']]

# %%
bins = [0, 1, 2, 3, 4, 5]
pd.cut(test_join['carat'], bins)
pd.cut(diamonds_join['carat'], bins)
# Out:
# 0        (1, 2]
# 1        (1, 2]
# 2        (0, 1]
# 3        (1, 2]
# 4        (1, 2]
#           ...
# 40450    (0, 1]
# 40451    (1, 2]
# 40452    (0, 1]
# 40453    (0, 1]
# 40454    (0, 1]
# Name: carat, Length: 40455, dtype: category
# Categories (5, interval[int64, right]): [(0, 1] < (1, 2] < (2, 3] < (3, 4] < (4, 5]]

# %%
test_join['carat_bins'] = pd.cut(test_join['carat'], bins)
# Out:
# /var/folders/mm/6t2s2cdd51n6bvy65ffxy6r40000gn/T/ipykernel_23559/2827804826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_join['carat_bins'] = pd.cut(test_join['carat'], bins)

# %%
diamonds_join['carat_bins'] = pd.cut(diamonds_join['carat'], bins)
# Out:
# /var/folders/mm/6t2s2cdd51n6bvy65ffxy6r40000gn/T/ipykernel_23559/4239624673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_join['carat_bins'] = pd.cut(diamonds_join['carat'], bins)

# %%
diamonds_join
# Out:
#        carat        cut color clarity  price carat_bins
# 0       1.21    Premium     J     VS2   4268     (1, 2]
# 1       1.20    Premium     J     VS2   4839     (1, 2]
# 2       0.30    Premium     J     VS2    368     (0, 1]
# 3       1.20    Premium     J     VS2   5053     (1, 2]
# 4       1.05    Premium     J     VS2   3593     (1, 2]
# ...      ...        ...   ...     ...    ...        ...
# 40450   0.59  Very Good     F      IF   2632     (0, 1]
# 40451   1.01  Very Good     F      IF   9972     (1, 2]
# 40452   0.30  Very Good     F      IF    886     (0, 1]
# 40453   0.71       Fair     F      IF   3205     (0, 1]
# 40454   0.37       Fair     F      IF   1166     (0, 1]
#
# [40455 rows x 6 columns]

# %%
test_join
# Out:
#        carat        cut color clarity         Price carat_bins
# 0       0.79  Very Good     F     SI1   3104.899477     (0, 1]
# 1       1.20      Ideal     J     VS1  10500.523732     (1, 2]
# 2       1.57    Premium     H     SI1  16743.195484     (1, 2]
# 3       0.90  Very Good     F     SI1   4184.487981     (0, 1]
# 4       0.50  Very Good     F     VS1   1197.624183     (0, 1]
# ...      ...        ...   ...     ...           ...        ...
# 13480   0.57      Ideal     E     SI1   2679.445271     (0, 1]
# 13481   0.71      Ideal     I     VS2   2764.651490     (0, 1]
# 13482   0.70      Ideal     F     VS1   2420.388605     (0, 1]
# 13483   0.70  Very Good     F     SI2   2331.395561     (0, 1]
# 13484   0.40      Ideal     I    VVS2    669.286265     (0, 1]
#
# [13485 rows x 6 columns]

# %%
test_join = test_join.groupby(['cut', 'color', 'clarity', 'carat_bins']).mean()
diamonds_join = diamonds_join.groupby(['cut', 'color', 'clarity', 'carat_bins']).mean()

# %%
test_join = test_join.dropna()

# %%
test_join
# Out:
#                                        carat         Price
# cut       color clarity carat_bins
# Fair      D     SI1     (0, 1]      0.830000   1635.819193
#                         (1, 2]      1.186667   2903.142222
#                 SI2     (0, 1]      0.806000   1432.886314
#                         (1, 2]      1.205000   2792.604583
#                 VS1     (0, 1]      0.710000   1068.952605
# ...                                      ...           ...
# Very Good J     VS2     (2, 3]      2.060000  17472.919743
#                 VVS1    (0, 1]      0.567778   1851.736916
#                         (1, 2]      1.600000  11401.045115
#                 VVS2    (0, 1]      0.440000   1101.966771
#                         (1, 2]      1.493333   8952.781889
#
# [587 rows x 2 columns]

# %%
a = pd.merge(test_join, diamonds_join, on=['cut', 'color', 'clarity','carat_bins'], how='left')
a
# Out:
#                                      carat_x         Price   carat_y  \
# cut       color clarity carat_bins
# Fair      D     SI1     (0, 1]      0.830000   1635.819193  0.736552
#                         (1, 2]      1.186667   2903.142222  1.132857
#                 SI2     (0, 1]      0.806000   1432.886314  0.817241
#                         (1, 2]      1.205000   2792.604583  1.220667
#                 VS1     (0, 1]      0.710000   1068.952605  0.610000
# ...                                      ...           ...       ...
# Very Good J     VS2     (2, 3]      2.060000  17472.919743  2.146818
#                 VVS1    (0, 1]      0.567778   1851.736916  0.603333
#                         (1, 2]      1.600000  11401.045115  1.305000
#                 VVS2    (0, 1]      0.440000   1101.966771  0.532500
#                         (1, 2]      1.493333   8952.781889  1.419286
#
#                                            price
# cut       color clarity carat_bins
# ...

# %%
a['diff'] = a['price']-a['Price']

# %%
a
# Out:
#                                            Price         price         diff
# cut       color clarity carat_bins
# Fair      D     SI1     (0, 1]       1635.819193   2694.000000  1058.180807
#                         (1, 2]       2903.142222   6256.857143  3353.714921
#                 SI2     (0, 1]       1432.886314   2724.793103  1291.906789
#                         (1, 2]       2792.604583   5694.400000  2901.795417
#                 VS1     (0, 1]       1068.952605   2964.750000  1895.797395
# ...                                          ...           ...          ...
# Very Good J     VS2     (2, 3]      17472.919743  14273.590909 -3199.328834
#                 VVS1    (0, 1]       1851.736916   1873.166667    21.429751
#                         (1, 2]      11401.045115   7590.500000 -3810.545115
#                 VVS2    (0, 1]       1101.966771   1471.500000   369.533229
#                         (1, 2]       8952.781889   8267.714286  -685.067603
#
# [587 rows x 3 columns]

# %%
a['diff'].mean()
# Out:
# -512.7120044607464

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(a['diff'])
 
# show plot
plt.show()

# %%
a = a.drop('carat_x', axis = 1)
a = a.drop('carat_y', axis = 1)

# %%
a
# Out:
#                                            Price         price
# cut       color clarity carat_bins
# Fair      D     SI1     (0, 1]       1635.819193   2694.000000
#                         (1, 2]       2903.142222   6256.857143
#                 SI2     (0, 1]       1432.886314   2724.793103
#                         (1, 2]       2792.604583   5694.400000
#                 VS1     (0, 1]       1068.952605   2964.750000
# ...                                          ...           ...
# Very Good J     VS2     (2, 3]      17472.919743  14273.590909
#                 VVS1    (0, 1]       1851.736916   1873.166667
#                         (1, 2]      11401.045115   7590.500000
#                 VVS2    (0, 1]       1101.966771   1471.500000
#                         (1, 2]       8952.781889   8267.714286
#
# [587 rows x 2 columns]

# %%
test['Price'].isna().sum()
# Out:
# 0
